# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.layers import Input, Activation, Conv2D, Flatten, Dense, MaxPooling2D,Dropout, Add, LeakyReLU, UpSampling2D
from keras.models import Model, load_model
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# # Load Dataset
# https://www.kaggle.com/datasets/kmader/finding-lungs-in-ct-data

# %%
x_train = np.load('dataset/x_train.npy')
y_train = np.load('dataset/y_train.npy')
x_val = np.load('dataset/x_val.npy')
y_val = np.load('dataset/y_val.npy')

# %%
print(x_train.shape, y_train.shape) # trainingset : 240 , image size : 256x256
print(x_val.shape, y_val.shape) # validationset : 27, grayscale
# Out:
# (240, 256, 256, 1) (240, 256, 256, 1)
# (27, 256, 256, 1) (27, 256, 256, 1)

# %% [markdown]
# # Build Model

# %%
inputs = Input(shape=(256, 256, 1))

# Encoder(downsampling)
net = Conv2D(32, kernel_size=3, activation='relu', padding='same')(inputs)
net = MaxPooling2D(pool_size=2, padding='same')(net)

net = Conv2D(64, kernel_size=3, activation='relu', padding='same')(net)
net = MaxPooling2D(pool_size=2, padding='same')(net)

net = Conv2D(128, kernel_size=3, activation='relu', padding='same')(net)
net = MaxPooling2D(pool_size=2, padding='same')(net)

net = Dense(128, activation='relu')(net)

# decoder(upsampling)

net = UpSampling2D(size=2)(net)
net = Conv2D(128, kernel_size=3, activation='sigmoid', padding='same')(net)

net = UpSampling2D(size=2)(net)
net = Conv2D(64, kernel_size=3, activation='sigmoid', padding='same')(net)

net = UpSampling2D(size=2)(net)
outputs = Conv2D(1, kernel_size=3, activation='sigmoid', padding='same')(net)

model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc', 'mse'])

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 32)      320
#
#  max_pooling2d_6 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)      18496
#
#  max_pooling2d_7 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  dense_2 (Dense)             (None, 32, 32, 128)       16512
#
#  up_sampling2d_6 (UpSampling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 128)       147584
#
#  up_sampling2d_7 (UpSampling  (None, 128, 128, 128)    0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 64)      73792
#
# ...

# %% [markdown]
# # Train

# %%
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=10, batch_size=32, callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, verbose=1, mode='auto', min_lr=1e-05)])
# Out:
# Epoch 1/10
# 8/8 [==============================] - 38s 5s/step - loss: 0.4185 - acc: 0.7586 - mse: 0.1393 - val_loss: 0.4211 - val_acc: 0.7467 - val_mse: 0.1442 - lr: 0.0010
# Epoch 2/10
# 8/8 [==============================] - 40s 5s/step - loss: 0.3956 - acc: 0.7607 - mse: 0.1325 - val_loss: 0.4074 - val_acc: 0.7467 - val_mse: 0.1402 - lr: 0.0010
# Epoch 3/10
# 8/8 [==============================] - 38s 5s/step - loss: 0.4121 - acc: 0.7678 - mse: 0.1394 - val_loss: 0.4006 - val_acc: 0.7449 - val_mse: 0.1356 - lr: 0.0010
# Epoch 4/10
# 8/8 [==============================] - 38s 5s/step - loss: 0.4053 - acc: 0.7627 - mse: 0.1367 - val_loss: 0.3974 - val_acc: 0.7467 - val_mse: 0.1359 - lr: 0.0010
# Epoch 5/10
# 8/8 [==============================] - 38s 5s/step - loss: 0.3684 - acc: 0.7819 - mse: 0.1232 - val_loss: 0.3876 - val_acc: 0.7705 - val_mse: 0.1324 - lr: 0.0010
# Epoch 6/10
# ...

# %% [markdown]
# # Evaluation

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 7))

ax[0, 0].set_title('loss')
ax[0, 0].plot(history.history['loss'], 'r')
ax[0, 1].set_title('acc')
ax[0, 1].plot(history.history['acc'], 'b')

ax[1, 0].set_title('val_loss')
ax[1, 0].plot(history.history['loss'], 'r--')
ax[1, 1].set_title('val_acc')
ax[1, 1].plot(history.history['acc'], 'b--')

# %%
preds = model.predict(x_val)

fig, ax = plt.subplots(len(x_val), 3, figsize=(10, 100))

for i, pred in enumerate(preds) :
    ax[i, 0].imshow(x_val[i].squeeze(), cmap='gray')
    ax[i, 1].imshow(y_val[i].squeeze(), cmap='gray')
    ax[i, 2].imshow(pred.squeeze(), cmap='gray')
# Out:
# 1/1 [==============================] - 1s 592ms/step
